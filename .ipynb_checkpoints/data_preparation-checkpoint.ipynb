# %%
# %pip install yfinance
import pandas as pd
import numpy as np
import requests
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime
import re
# Out:
# Collecting yfinance
#   Using cached yfinance-0.2.66-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pandas>=1.3.0 in /Users/andrewlee/myenv/lib/python3.13/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/andrewlee/myenv/lib/python3.13/site-packages (from yfinance) (2.2.4)
# Requirement already satisfied: requests>=2.31 in /Users/andrewlee/myenv/lib/python3.13/site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/andrewlee/myenv/lib/python3.13/site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in /Users/andrewlee/myenv/lib/python3.13/site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.3.tar.gz (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 21.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Using cached beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/andrewlee/myenv/lib/python3.13/site-packages (from yfinance) (6.33.0)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.11.1->yfinance)
#   Using cached soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/andrewlee/myenv/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.13.2)
# Collecting cffi>=1.12.0 (from curl_cffi>=0.7->yfinance)
#   Downloading cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Requirement already satisfied: certifi>=2024.2.2 in /Users/andrewlee/myenv/lib/python3.13/site-packages (from curl_cffi>=0.7->yfinance) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/andrewlee/myenv/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/andrewlee/myenv/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/andrewlee/myenv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/andrewlee/myenv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/andrewlee/myenv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (2.5.0)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi>=0.7->yfinance)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Requirement already satisfied: six>=1.5 in /Users/andrewlee/myenv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Downloading yfinance-0.2.66-py2.py3-none-any.whl (123 kB)
# Using cached beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 26.3 MB/s eta 0:00:00
# Downloading frozendict-2.4.7-py3-none-any.whl (16 kB)
# Downloading websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Downloading cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl (181 kB)
# Using cached soupsieve-2.8-py3-none-any.whl (36 kB)
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Building wheels for collected packages: multitasking, peewee
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15633 sha256=440c22acc19ece4cada0dcac7bccaa674cade0961584e8614f35646bfd8d5edd
#   Stored in directory: /Users/andrewlee/Library/Caches/pip/wheels/1e/df/0f/e2bbb22d689b30c681feb5410ab64a2523437b34c8ecfc6476
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.18.3-cp313-cp313-macosx_14_0_arm64.whl size=281694 sha256=61879cb1c2122a82dc4f8192540aeda1de4025ed42384f0c645af50ec40b5220
#   Stored in directory: /Users/andrewlee/Library/Caches/pip/wheels/8c/a9/a4/df972cd49f865ffde174d9c5b26f14f08f8a363ed31e10ff91
# Successfully built multitasking peewee
# Installing collected packages: peewee, multitasking, websockets, soupsieve, pycparser, frozendict, cffi, beautifulsoup4, curl_cffi, yfinance
# Successfully installed beautifulsoup4-4.14.2 cffi-2.0.0 curl_cffi-0.13.0 frozendict-2.4.7 multitasking-0.0.12 peewee-3.18.3 pycparser-2.23 soupsieve-2.8 websockets-15.0.1 yfinance-0.2.66
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: /Users/andrewlee/myenv/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load Truth Social Data
url = "https://stilesdata.com/trump-truth-social-archive/truth_archive.json"
response = requests.get(url)
truth_data = response.json()

df_truth = pd.DataFrame(truth_data)
print(f"Total posts: {len(df_truth)}")
df_truth.head()
# Out:
# Total posts: 29409
#                    id                created_at  \
# 0  115437112529618205  2025-10-25T22:15:50.076Z
# 1  115436984200406691  2025-10-25T21:43:11.929Z
# 2  115436968622280698  2025-10-25T21:39:14.264Z
# 3  115436967550742005  2025-10-25T21:38:57.913Z
# 4  115436966353094571  2025-10-25T21:38:39.636Z
#
#                                              content  \
# 0  I am on my way to Malaysia, where I will sign ...
# 1  RT @realDonaldTrumpCanada was caught, red hand...
# 2  https://www.dailysignal.com/2025/10/22/trumps-...
# 3  https://www.foxnews.com/opinion/new-high-tech-...
# 4  https://www.foxnews.com/politics/scoop-trumps-...
#
#                                                  url media  replies_count  \
# 0  https://truthsocial.com/@realDonaldTrump/11543...    []         1134.0
# 1  https://truthsocial.com/@realDonaldTrump/11543...    []            0.0
# 2  https://truthsocial.com/@realDonaldTrump/11543...    []          302.0
# 3  https://truthsocial.com/@realDonaldTrump/11543...    []          214.0
# 4  https://truthsocial.com/@realDonaldTrump/11543...    []          211.0
#
#    reblogs_count  favourites_count
# 0         3088.0           12468.0
# 1            0.0               1.0
# 2         1582.0            6018.0
# 3         1515.0            5878.0
# 4         1756.0            6224.0

# %%
# Clean Truth Social Data
df_truth['timestamp'] = pd.to_datetime(df_truth['created_at'])
df_truth['date'] = df_truth['timestamp'].dt.date

# Basic text cleaning
def clean_text(text):
    if pd.isna(text):
        return ""
    
    # Remove URLs
    text = re.sub(r'http\S+', '', text)
    
     # Remove hashtags
    text = re.sub(r'#\w+', '', text)
    text = text.strip()
    return text

df_truth['cleaned_content'] = df_truth['content'].apply(clean_text)

# Filter out empty posts
df_truth = df_truth[df_truth['cleaned_content'] != ""]
print(f"Posts after cleaning: {len(df_truth)}")
df_truth.head()
# Out:
# Posts after cleaning: 18778
#                     id                created_at  \
# 0   115437112529618205  2025-10-25T22:15:50.076Z
# 1   115436984200406691  2025-10-25T21:43:11.929Z
# 8   115436697060819133  2025-10-25T20:30:10.525Z
# 9   115436558661444946  2025-10-25T19:54:58.713Z
# 11  115436151669143136  2025-10-25T18:11:28.545Z
#
#                                               content  \
# 0   I am on my way to Malaysia, where I will sign ...
# 1   RT @realDonaldTrumpCanada was caught, red hand...
# 8   Canada was caught, red handed, putting up a fr...
# 9   We have a very strong PEACE in the Middle East...
# 11  Congressman Jimmy Patronis is a MAGA Warrior w...
#
#                                                   url media  replies_count  \
# 0   https://truthsocial.com/@realDonaldTrump/11543...    []         1134.0
# 1   https://truthsocial.com/@realDonaldTrump/11543...    []            0.0
# 8   https://truthsocial.com/@realDonaldTrump/11543...    []          401.0
# 9   https://truthsocial.com/@realDonaldTrump/11543...    []          470.0
# 11  https://truthsocial.com/@realDonaldTrump/11543...    []          313.0
#
#     reblogs_count  favourites_count                        timestamp  \
# 0          3088.0           12468.0 2025-10-25 22:15:50.076000+00:00
# 1             0.0               1.0 2025-10-25 21:43:11.929000+00:00
# 8           831.0            2715.0 2025-10-25 20:30:10.525000+00:00
# 9          1314.0            4887.0 2025-10-25 19:54:58.713000+00:00
# 11         1260.0            5237.0 2025-10-25 18:11:28.545000+00:00
#
#           date                                    cleaned_content
# 0   2025-10-25  I am on my way to Malaysia, where I will sign ...
# 1   2025-10-25  RT @realDonaldTrumpCanada was caught, red hand...
# 8   2025-10-25  Canada was caught, red handed, putting up a fr...
# 9   2025-10-25  We have a very strong PEACE in the Middle East...
# 11  2025-10-25  Congressman Jimmy Patronis is a MAGA Warrior w...

# %%
# Load QQQ Market Data
qqq = yf.download('QQQ', start='2022-01-01', end=datetime.now().strftime('%Y-%m-%d'))

# Flatten column names
if isinstance(qqq.columns, pd.MultiIndex):
    qqq.columns = [col[0] for col in qqq.columns]

# Calculate daily returns
qqq['Returns'] = qqq['Close'].pct_change() * 100

print(f"Market data from {qqq.index[0]} to {qqq.index[-1]}")
qqq.head()
# Out:
# /var/folders/xq/pddn9j1n1wq71m29wwc_vjrh0000gn/T/ipykernel_14296/3965202336.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   qqq = yf.download('QQQ', start='2022-01-01', end=datetime.now().strftime('%Y-%m-%d'))
# [*********************100%***********************]  1 of 1 completed
# Market data from 2022-01-03 00:00:00 to 2025-11-13 00:00:00
#                  Close        High         Low        Open    Volume   Returns
# Date
# 2022-01-03  392.184113  392.437976  387.497598  389.616282  40575900       NaN
# 2022-01-04  387.097290  392.769937  383.992474  392.730874  58027200 -1.297050
# 2022-01-05  375.205170  386.530945  374.951307  385.408108  75739800 -3.072127
# 2022-01-06  374.941589  378.192883  371.143566  373.379438  70814300 -0.070250
# 2022-01-07  370.879913  376.640458  369.102962  374.951346  72652300 -1.083282

# %%
# Align Data by Date

# Count posts per day
daily_posts = df_truth.groupby('date').size().reset_index(name='post_count')
daily_posts['date'] = pd.to_datetime(daily_posts['date'])

# Merge with market data
qqq_reset = qqq.reset_index()
qqq_reset['date'] = pd.to_datetime(qqq_reset['Date']).dt.date
daily_posts['date'] = daily_posts['date'].dt.date

combined_df = pd.merge(qqq_reset, daily_posts, on='date', how='left')
combined_df['post_count'] = combined_df['post_count'].fillna(0)

print(f"Combined dataset: {len(combined_df)} days")
combined_df.head()
# Out:
# Combined dataset: 971 days
#         Date       Close        High         Low        Open    Volume  \
# 0 2022-01-03  392.184113  392.437976  387.497598  389.616282  40575900
# 1 2022-01-04  387.097290  392.769937  383.992474  392.730874  58027200
# 2 2022-01-05  375.205170  386.530945  374.951307  385.408108  75739800
# 3 2022-01-06  374.941589  378.192883  371.143566  373.379438  70814300
# 4 2022-01-07  370.879913  376.640458  369.102962  374.951346  72652300
#
#     Returns        date  post_count
# 0       NaN  2022-01-03         0.0
# 1 -1.297050  2022-01-04         0.0
# 2 -3.072127  2022-01-05         0.0
# 3 -0.070250  2022-01-06         0.0
# 4 -1.083282  2022-01-07         0.0

# %%
# Save cleaned data
df_truth.to_csv('truth_social_cleaned.csv', index=False)
combined_df.to_csv('combined_data.csv', index=False)

print("Data saved successfully!")
# Out:
# Data saved successfully!

# %%
# Plot posts over time
plt.figure(figsize=(12, 4))
plt.plot(combined_df['date'], combined_df['post_count'])
plt.title('Trump Truth Social Posts Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Posts')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot QQQ returns
plt.figure(figsize=(12, 4))
plt.plot(combined_df['date'], combined_df['Returns'])
plt.title('QQQ Daily Returns')
plt.xlabel('Date')
plt.ylabel('Returns (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
